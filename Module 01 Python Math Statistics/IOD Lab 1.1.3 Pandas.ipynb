# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Pandas Exploration
#
# This lab provides practice in using the pandas library to carry out the following tasks:
#
# 1. Understanding data types
# 2. Querying a dataframe
# 3. Using the index to sort a dataframe
# 4. Visualizing and summarizing columns of a dataframe

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
# get matplot to show charts inline
# %matplotlib inline

# %% [markdown]
# chrome://settings/content/cookies
#
# NOTE: Make sure third party cookies are not blocked.

# %%
df = pd.read_csv("../Lab data files/Employee-attrition.csv") # this comes from the DATA folder

# %%
df.head(10)
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
# 5        1318  12/31/2011 0:00      1/3/1954        8/28/1989
# 6        1318  12/31/2012 0:00      1/3/1954        8/28/1989
# 7        1318  12/31/2013 0:00      1/3/1954        8/28/1989
# 8        1318  12/31/2014 0:00      1/3/1954        8/28/1989
# 9        1318  12/31/2015 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
# 3            1/1/1900   55                 20  Vancouver       Executive
# 4            1/1/1900   56                 21  Vancouver       Executive
# 5            1/1/1900   57                 22  Vancouver       Executive
# 6            1/1/1900   58                 23  Vancouver       Executive
# 7            1/1/1900   59                 24  Vancouver       Executive
# 8            1/1/1900   60                 25  Vancouver       Executive
# 9            1/1/1900   61                 26  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# 1       CEO          35            M        Male  Not Applicable
# 2       CEO          35            M        Male  Not Applicable
# 3       CEO          35            M        Male  Not Applicable
# 4       CEO          35            M        Male  Not Applicable
# 5       CEO          35            M        Male  Not Applicable
# 6       CEO          35            M        Male  Not Applicable
# 7       CEO          35            M        Male  Not Applicable
# 8       CEO          35            M        Male  Not Applicable
# 9       CEO          35            M        Male  Not Applicable
#
#     termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# 0  Not Applicable         2006  ACTIVE    HEADOFFICE
# 1  Not Applicable         2007  ACTIVE    HEADOFFICE
# 2  Not Applicable         2008  ACTIVE    HEADOFFICE
# 3  Not Applicable         2009  ACTIVE    HEADOFFICE
# 4  Not Applicable         2010  ACTIVE    HEADOFFICE
# 5  Not Applicable         2011  ACTIVE    HEADOFFICE
# 6  Not Applicable         2012  ACTIVE    HEADOFFICE
# 7  Not Applicable         2013  ACTIVE    HEADOFFICE
# 8  Not Applicable         2014  ACTIVE    HEADOFFICE
# 9  Not Applicable         2015  ACTIVE    HEADOFFICE

# %%
df.tail()
# Out:
#        EmployeeID  recorddate_key birthdate_key orighiredate_key  \
# 49648        8258  12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264   8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279  12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296  12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321  12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 49648          12/30/2015   21                  2    Valemount
# 49649           8/30/2013   19                  0    Vancouver
# 49650          12/30/2015   21                  2   White Rock
# 49651          12/31/2013   19                  0      Kelowna
# 49652          12/30/2014   20                  1  Grand Forks
#
#         department_name     job_title  store_name gender_short gender_full  \
# 49648             Dairy  Dairy Person          34            M        Male
# 49649  Customer Service       Cashier          44            F      Female
# 49650  Customer Service       Cashier          39            F      Female
# 49651  Customer Service       Cashier          16            F      Female
# 49652  Customer Service       Cashier          13            F      Female
#
#       termreason_desc termtype_desc  STATUS_YEAR      STATUS BUSINESS_UNIT
# 49648          Layoff   Involuntary         2015  TERMINATED        STORES
# 49649      Resignaton     Voluntary         2013  TERMINATED        STORES
# 49650          Layoff   Involuntary         2015  TERMINATED        STORES
# 49651      Resignaton     Voluntary         2013  TERMINATED        STORES
# 49652          Layoff   Involuntary         2014  TERMINATED        STORES

# %% [markdown]
# # Accessing the main DataFrame components

# %%
columns = df.columns
index = df.index
data = df.values

# %%
columns
# Out:
# Index(['EmployeeID', 'recorddate_key', 'birthdate_key', 'orighiredate_key',
#        'terminationdate_key', 'age', 'length_of_service', 'city_name',
#        'department_name', 'job_title', 'store_name', 'gender_short',
#        'gender_full', 'termreason_desc', 'termtype_desc', 'STATUS_YEAR',
#        'STATUS', 'BUSINESS_UNIT'],
#       dtype='object')

# %%
index
# Out:
# RangeIndex(start=0, stop=49653, step=1)

# %%
data
# Out:
# array([[1318, '12/31/2006 0:00', '1/3/1954', ..., 2006, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2007 0:00', '1/3/1954', ..., 2007, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2008 0:00', '1/3/1954', ..., 2008, 'ACTIVE',
#         'HEADOFFICE'],
#        ...,
#        [8279, '12/1/2015 0:00', '7/18/1994', ..., 2015, 'TERMINATED',
#         'STORES'],
#        [8296, '12/1/2013 0:00', '9/2/1994', ..., 2013, 'TERMINATED',
#         'STORES'],
#        [8321, '12/1/2014 0:00', '11/28/1994', ..., 2014, 'TERMINATED',
#         'STORES']], dtype=object)

# %% [markdown]
# # 1. Understanding Data Types

# %% [markdown]
# #### 1.A Find the shape of the dataframe

# %%
df.shape
# Out:
# (49653, 18)

# %% [markdown]
# #### 1.B Find the data types of the dataframe

# %%
df.dtypes
# Out:
# EmployeeID              int64
# recorddate_key         object
# birthdate_key          object
# orighiredate_key       object
# terminationdate_key    object
# age                     int64
# length_of_service       int64
# city_name              object
# department_name        object
# job_title              object
# store_name              int64
# gender_short           object
# gender_full            object
# termreason_desc        object
# termtype_desc          object
# STATUS_YEAR             int64
# STATUS                 object
# BUSINESS_UNIT          object
# dtype: object

# %% [markdown]
# #### 1.C Find the number of data types in the dataframe
#
#
#
# ```
# Expected Output:
# object    13
# int64      5
# dtype: int64
# ```

# %%
df.dtypes.value_counts()
# Out:
# object    13
# int64      5
# Name: count, dtype: int64

# %% [markdown]
# #### 1.D Use Info
#
# Use info and explore the difference.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49653 entries, 0 to 49652
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EmployeeID           49653 non-null  int64
#  1   recorddate_key       49653 non-null  object
#  2   birthdate_key        49653 non-null  object
#  3   orighiredate_key     49653 non-null  object
#  4   terminationdate_key  49653 non-null  object
#  5   age                  49653 non-null  int64
#  6   length_of_service    49653 non-null  int64
#  7   city_name            49653 non-null  object
#  8   department_name      49653 non-null  object
#  9   job_title            49653 non-null  object
#  10  store_name           49653 non-null  int64
#  11  gender_short         49653 non-null  object
#  12  gender_full          49653 non-null  object
#  13  termreason_desc      49653 non-null  object
#  14  termtype_desc        49653 non-null  object
#  15  STATUS_YEAR          49653 non-null  int64
#  16  STATUS               49653 non-null  object
#  17  BUSINESS_UNIT        49653 non-null  object
# dtypes: int64(5), object(13)
# memory usage: 6.8+ MB

# %% [markdown]
# # 2. Querying the Dataframe

# %% [markdown]
# #### 2.A Check Values of the `job_title` column

# %%
df.job_title
# Out:
# 0                 CEO
# 1                 CEO
# 2                 CEO
# 3                 CEO
# 4                 CEO
#              ...
# 49648    Dairy Person
# 49649         Cashier
# 49650         Cashier
# 49651         Cashier
# 49652         Cashier
# Name: job_title, Length: 49653, dtype: object

# %% [markdown]
# #### 2.B Find how many rows are in each job title
#
#
#
# ```
# # Expected Output
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# .
# .
# .
# ```

# %%
df.job_title.value_counts()
# Out:
# job_title
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# Baker                              8096
# Cashier                            6816
# Shelf Stocker                      5622
# Customer Service Manager            306
# Processed Foods Manager             289
# Meats Manager                       285
# Bakery Manager                      285
# Produce Manager                     278
# Store Manager                       271
# Recruiter                            62
# HRIS Analyst                         55
# Accounting Clerk                     50
# Benefits Admin                       35
# Accounts Receiveable Clerk           30
# Labor Relations Analyst              30
# Trainer                              26
# Accounts Payable Clerk               25
# Investment Analyst                   20
# Auditor                              20
# Systems Analyst                      20
# Compensation Analyst                 20
# Corporate Lawyer                     17
# Legal Counsel                        10
# VP Human Resources                   10
# CEO                                  10
# VP Stores                            10
# VP Finance                           10
# Exec Assistant, Legal Counsel        10
# Exec Assistant, Human Resources      10
# CHief Information Officer            10
# Director, Recruitment                10
# Exec Assistant, Finance              10
# Exec Assistant, VP Stores            10
# Director, Employee Records            9
# Director, HR Technology               9
# Director, Accounting                  9
# Dairy Manager                         9
# Director, Accounts Payable            9
# Director, Accounts Receivable         9
# Director, Training                    4
# Director, Labor Relations             4
# Director, Audit                       4
# Director, Compensation                4
# Director, Investments                 4
# Name: count, dtype: int64

# %% [markdown]
# #### 2.C Find rows where `job_title` is CEO

# %%
df[df.job_title == 'CEO']
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
# 5        1318  12/31/2011 0:00      1/3/1954        8/28/1989
# 6        1318  12/31/2012 0:00      1/3/1954        8/28/1989
# 7        1318  12/31/2013 0:00      1/3/1954        8/28/1989
# 8        1318  12/31/2014 0:00      1/3/1954        8/28/1989
# 9        1318  12/31/2015 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
# 3            1/1/1900   55                 20  Vancouver       Executive
# 4            1/1/1900   56                 21  Vancouver       Executive
# 5            1/1/1900   57                 22  Vancouver       Executive
# 6            1/1/1900   58                 23  Vancouver       Executive
# 7            1/1/1900   59                 24  Vancouver       Executive
# 8            1/1/1900   60                 25  Vancouver       Executive
# 9            1/1/1900   61                 26  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# 1       CEO          35            M        Male  Not Applicable
# 2       CEO          35            M        Male  Not Applicable
# 3       CEO          35            M        Male  Not Applicable
# 4       CEO          35            M        Male  Not Applicable
# 5       CEO          35            M        Male  Not Applicable
# 6       CEO          35            M        Male  Not Applicable
# 7       CEO          35            M        Male  Not Applicable
# 8       CEO          35            M        Male  Not Applicable
# 9       CEO          35            M        Male  Not Applicable
#
#     termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# 0  Not Applicable         2006  ACTIVE    HEADOFFICE
# 1  Not Applicable         2007  ACTIVE    HEADOFFICE
# 2  Not Applicable         2008  ACTIVE    HEADOFFICE
# 3  Not Applicable         2009  ACTIVE    HEADOFFICE
# 4  Not Applicable         2010  ACTIVE    HEADOFFICE
# 5  Not Applicable         2011  ACTIVE    HEADOFFICE
# 6  Not Applicable         2012  ACTIVE    HEADOFFICE
# 7  Not Applicable         2013  ACTIVE    HEADOFFICE
# 8  Not Applicable         2014  ACTIVE    HEADOFFICE
# 9  Not Applicable         2015  ACTIVE    HEADOFFICE

# %% [markdown]
# #### 2.D Describe `age`
#
# Find the count, mean, std, min, max of the column 'age'

# %%
df.age.describe()
# Out:
# count    49653.000000
# mean        42.077035
# std         12.427257
# min         19.000000
# 25%         31.000000
# 50%         42.000000
# 75%         53.000000
# max         65.000000
# Name: age, dtype: float64

# %% [markdown]
# #### 2.E Group by `age` and find how many there are of each age

# %%
df.groupby('age')['age'].count()
# Out:
# age
# 19     158
# 20     408
# 21     703
# 22     815
# 23     960
# 24    1111
# 25    1197
# 26    1210
# 27    1235
# 28    1225
# 29    1227
# 30    1212
# 31    1146
# 32    1153
# 33    1164
# 34    1188
# 35    1189
# 36    1176
# 37    1149
# 38    1156
# 39    1142
# 40    1130
# 41    1135
# 42    1152
# 43    1150
# 44    1157
# 45    1141
# 46    1161
# 47    1173
# 48    1180
# 49    1196
# 50    1218
# 51    1207
# 52    1188
# 53    1188
# 54    1159
# 55    1168
# 56    1154
# 57    1130
# 58    1130
# 59    1128
# 60    1109
# 61     757
# 62     712
# 63     667
# 64     646
# 65     593
# Name: age, dtype: int64

# %% [markdown]
# ##### 2.F [BONUS] Describe all numeric columns of the dataframe
#
# Find the count, mean, std, min, max of all columns of the dataframe

# %%
df.describe()
# Out:
#          EmployeeID           age  length_of_service    store_name  \
# count  49653.000000  49653.000000       49653.000000  49653.000000
# mean    4859.495740     42.077035          10.434596     27.297605
# std     1826.571142     12.427257           6.325286     13.514134
# min     1318.000000     19.000000           0.000000      1.000000
# 25%     3360.000000     31.000000           5.000000     16.000000
# 50%     5031.000000     42.000000          10.000000     28.000000
# 75%     6335.000000     53.000000          15.000000     42.000000
# max     8336.000000     65.000000          26.000000     46.000000
#
#         STATUS_YEAR
# count  49653.000000
# mean    2010.612612
# std        2.845577
# min     2006.000000
# 25%     2008.000000
# 50%     2011.000000
# 75%     2013.000000
# max     2015.000000

# %% [markdown]
# # 3. Make the index meaningful by making `EmployeeID` the index

# %%
df.set_index('EmployeeID')
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 1318        12/31/2006 0:00      1/3/1954        8/28/1989
# 1318        12/31/2007 0:00      1/3/1954        8/28/1989
# 1318        12/31/2008 0:00      1/3/1954        8/28/1989
# 1318        12/31/2009 0:00      1/3/1954        8/28/1989
# 1318        12/31/2010 0:00      1/3/1954        8/28/1989
# ...                     ...           ...              ...
# 8258         12/1/2015 0:00     5/28/1994        8/19/2013
# 8264          8/1/2013 0:00     6/13/1994        8/27/2013
# 8279         12/1/2015 0:00     7/18/1994        9/15/2013
# 8296         12/1/2013 0:00      9/2/1994        10/9/2013
# 8321         12/1/2014 0:00    11/28/1994       11/24/2013
#
#            terminationdate_key  age  length_of_service    city_name  \
# EmployeeID
# 1318                  1/1/1900   52                 17    Vancouver
# 1318                  1/1/1900   53                 18    Vancouver
# 1318                  1/1/1900   54                 19    Vancouver
# 1318                  1/1/1900   55                 20    Vancouver
# 1318                  1/1/1900   56                 21    Vancouver
# ...                        ...  ...                ...          ...
# 8258                12/30/2015   21                  2    Valemount
# 8264                 8/30/2013   19                  0    Vancouver
# 8279                12/30/2015   21                  2   White Rock
# 8296                12/31/2013   19                  0      Kelowna
# 8321                12/30/2014   20                  1  Grand Forks
#
#              department_name     job_title  store_name gender_short  \
# EmployeeID
# 1318               Executive           CEO          35            M
# 1318               Executive           CEO          35            M
# 1318               Executive           CEO          35            M
# 1318               Executive           CEO          35            M
# 1318               Executive           CEO          35            M
# ...                      ...           ...         ...          ...
# 8258                   Dairy  Dairy Person          34            M
# 8264        Customer Service       Cashier          44            F
# 8279        Customer Service       Cashier          39            F
# 8296        Customer Service       Cashier          16            F
# 8321        Customer Service       Cashier          13            F
#
#            gender_full termreason_desc   termtype_desc  STATUS_YEAR  \
# EmployeeID
# 1318              Male  Not Applicable  Not Applicable         2006
# 1318              Male  Not Applicable  Not Applicable         2007
# 1318              Male  Not Applicable  Not Applicable         2008
# 1318              Male  Not Applicable  Not Applicable         2009
# 1318              Male  Not Applicable  Not Applicable         2010
# ...                ...             ...             ...          ...
# 8258              Male          Layoff     Involuntary         2015
# 8264            Female      Resignaton       Voluntary         2013
# 8279            Female          Layoff     Involuntary         2015
# 8296            Female      Resignaton       Voluntary         2013
# 8321            Female          Layoff     Involuntary         2014
#
#                 STATUS BUSINESS_UNIT
# EmployeeID
# 1318            ACTIVE    HEADOFFICE
# 1318            ACTIVE    HEADOFFICE
# 1318            ACTIVE    HEADOFFICE
# 1318            ACTIVE    HEADOFFICE
# 1318            ACTIVE    HEADOFFICE
# ...                ...           ...
# 8258        TERMINATED        STORES
# 8264        TERMINATED        STORES
# 8279        TERMINATED        STORES
# 8296        TERMINATED        STORES
# 8321        TERMINATED        STORES
#
# [49653 rows x 17 columns]

# %% [markdown]
# #### 3.A Find a specific row using the index

# %%
df[30:31]
# Out:
#     EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 30        1321  12/31/2006 0:00      1/2/1959        8/28/1989
#
#    terminationdate_key  age  length_of_service  city_name department_name  \
# 30            1/1/1900   47                 17  Vancouver       Executive
#
#              job_title  store_name gender_short gender_full termreason_desc  \
# 30  VP Human Resources          35            M        Male  Not Applicable
#
#      termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# 30  Not Applicable         2006  ACTIVE    HEADOFFICE

# %%
df.iloc[30, :]
# Out:
# EmployeeID                           1321
# recorddate_key            12/31/2006 0:00
# birthdate_key                    1/2/1959
# orighiredate_key                8/28/1989
# terminationdate_key              1/1/1900
# age                                    47
# length_of_service                      17
# city_name                       Vancouver
# department_name                 Executive
# job_title              VP Human Resources
# store_name                             35
# gender_short                            M
# gender_full                          Male
# termreason_desc            Not Applicable
# termtype_desc              Not Applicable
# STATUS_YEAR                          2006
# STATUS                             ACTIVE
# BUSINESS_UNIT                  HEADOFFICE
# Name: 30, dtype: object

# %% [markdown]
# #### 3.B Sort the dataframe using the index

# %%
df.sort_index()
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0            1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1            1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2            1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3            1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4            1318  12/31/2010 0:00      1/3/1954        8/28/1989
# ...           ...              ...           ...              ...
# 49648        8258   12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264    8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279   12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296   12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321   12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 0                1/1/1900   52                 17    Vancouver
# 1                1/1/1900   53                 18    Vancouver
# 2                1/1/1900   54                 19    Vancouver
# 3                1/1/1900   55                 20    Vancouver
# 4                1/1/1900   56                 21    Vancouver
# ...                   ...  ...                ...          ...
# 49648          12/30/2015   21                  2    Valemount
# 49649           8/30/2013   19                  0    Vancouver
# 49650          12/30/2015   21                  2   White Rock
# 49651          12/31/2013   19                  0      Kelowna
# 49652          12/30/2014   20                  1  Grand Forks
#
#         department_name     job_title  store_name gender_short gender_full  \
# 0             Executive           CEO          35            M        Male
# 1             Executive           CEO          35            M        Male
# 2             Executive           CEO          35            M        Male
# 3             Executive           CEO          35            M        Male
# 4             Executive           CEO          35            M        Male
# ...                 ...           ...         ...          ...         ...
# 49648             Dairy  Dairy Person          34            M        Male
# 49649  Customer Service       Cashier          44            F      Female
# 49650  Customer Service       Cashier          39            F      Female
# 49651  Customer Service       Cashier          16            F      Female
# 49652  Customer Service       Cashier          13            F      Female
#
#       termreason_desc   termtype_desc  STATUS_YEAR      STATUS BUSINESS_UNIT
# 0      Not Applicable  Not Applicable         2006      ACTIVE    HEADOFFICE
# 1      Not Applicable  Not Applicable         2007      ACTIVE    HEADOFFICE
# 2      Not Applicable  Not Applicable         2008      ACTIVE    HEADOFFICE
# 3      Not Applicable  Not Applicable         2009      ACTIVE    HEADOFFICE
# 4      Not Applicable  Not Applicable         2010      ACTIVE    HEADOFFICE
# ...               ...             ...          ...         ...           ...
# 49648          Layoff     Involuntary         2015  TERMINATED        STORES
# 49649      Resignaton       Voluntary         2013  TERMINATED        STORES
# 49650          Layoff     Involuntary         2015  TERMINATED        STORES
# 49651      Resignaton       Voluntary         2013  TERMINATED        STORES
# 49652          Layoff     Involuntary         2014  TERMINATED        STORES
#
# [49653 rows x 18 columns]

# %% [markdown]
# ##### 3.C [BONUS] Sort the dataframe using `age`

# %%
df.sort_values(by="age")
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 49649        8264    8/1/2013 0:00     6/13/1994        8/27/2013
# 49651        8296   12/1/2013 0:00      9/2/1994        10/9/2013
# 47504        8091  12/31/2012 0:00      1/6/1993       11/23/2012
# 47516        8094  12/31/2012 0:00     1/16/1993       11/29/2012
# 47520        8095  12/31/2012 0:00     1/16/1993       11/29/2012
# ...           ...              ...           ...              ...
# 48430        2348    3/1/2006 0:00      3/7/1941        9/12/1992
# 48429        2342    2/1/2006 0:00     2/28/1941         9/4/1992
# 48428        2337    2/1/2006 0:00     2/22/1941        8/29/1992
# 48427        2332    2/1/2006 0:00     2/14/1941        8/21/1992
# 48392        1695   12/1/2015 0:00    12/28/1950        9/15/1990
#
#       terminationdate_key  age  length_of_service        city_name  \
# 49649           8/30/2013   19                  0        Vancouver
# 49651          12/31/2013   19                  0          Kelowna
# 47504            1/1/1900   19                  0    Prince George
# 47516            1/1/1900   19                  0  New Westminster
# 47520            1/1/1900   19                  0       Abbotsford
# ...                   ...  ...                ...              ...
# 48430            3/7/2006   65                 13          Terrace
# 48429           2/28/2006   65                 13          Nanaimo
# 48428           2/22/2006   65                 13  New Westminster
# 48427           2/14/2006   65                 13       Chilliwack
# 48392          12/28/2015   65                 25        Vancouver
#
#         department_name                 job_title  store_name gender_short  \
# 49649  Customer Service                   Cashier          44            F
# 49651  Customer Service                   Cashier          16            F
# 47504  Customer Service                   Cashier          26            M
# 47516  Customer Service                   Cashier          21            F
# 47520  Customer Service                   Cashier           1            F
# ...                 ...                       ...         ...          ...
# 48430             Dairy              Dairy Person          32            F
# 48429             Meats               Meat Cutter          18            F
# 48428             Meats               Meat Cutter          21            F
# 48427             Dairy              Dairy Person           6            F
# 48392  Customer Service  Customer Service Manager          42            F
#
#       gender_full termreason_desc   termtype_desc  STATUS_YEAR      STATUS  \
# 49649      Female      Resignaton       Voluntary         2013  TERMINATED
# 49651      Female      Resignaton       Voluntary         2013  TERMINATED
# 47504        Male  Not Applicable  Not Applicable         2012      ACTIVE
# 47516      Female  Not Applicable  Not Applicable         2012      ACTIVE
# 47520      Female  Not Applicable  Not Applicable         2012      ACTIVE
# ...           ...             ...             ...          ...         ...
# 48430      Female      Retirement       Voluntary         2006  TERMINATED
# 48429      Female      Retirement       Voluntary         2006  TERMINATED
# 48428      Female      Retirement       Voluntary         2006  TERMINATED
# 48427      Female      Retirement       Voluntary         2006  TERMINATED
# 48392      Female      Retirement       Voluntary         2015  TERMINATED
#
#       BUSINESS_UNIT
# 49649        STORES
# 49651        STORES
# 47504        STORES
# 47516        STORES
# 47520        STORES
# ...             ...
# 48430        STORES
# 48429        STORES
# 48428        STORES
# 48427        STORES
# 48392        STORES
#
# [49653 rows x 18 columns]

# %% [markdown]
# ##### 3.D [BONUS] Using `sample` select any row

# %%
df.sample()
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 31573        5861  12/31/2015 0:00     9/20/1975        10/7/2003
#
#       terminationdate_key  age  length_of_service  city_name department_name  \
# 31573            1/1/1900   40                 12  Vancouver           Meats
#
#          job_title  store_name gender_short gender_full termreason_desc  \
# 31573  Meat Cutter          43            M        Male  Not Applicable
#
#         termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# 31573  Not Applicable         2015  ACTIVE        STORES

# %% [markdown]
# # 4. Visualization

# %% [markdown]
# #### 4.A Plot a histogram of `age`

# %%
df.hist("age")
# Out:
# array([[<Axes: title={'center': 'age'}>]], dtype=object)

# %% [markdown]
# #### 4.B BoxPlot of `age`

# %%
df.boxplot('age')
# Out:
# <Axes: >

# %% [markdown]
# #### 4.C Create a scatterplot of `age` and `length_of_service`

# %%
df.plot.scatter(x="age", y="length_of_service")
# Out:
# <Axes: xlabel='age', ylabel='length_of_service'>

# %% [markdown]
# #### 4.D Print a statistical summary of `age`

# %%
df.age.describe()
# Out:
# count    49653.000000
# mean        42.077035
# std         12.427257
# min         19.000000
# 25%         31.000000
# 50%         42.000000
# 75%         53.000000
# max         65.000000
# Name: age, dtype: float64

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2024 Institute of Data
#
#
# ---
#
#
#
# ---
